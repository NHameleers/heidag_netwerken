# %%
import pandas as pd

# %%
def drop_niet_blokken(df):
    '''Unit is een combinatie van 4 cijfers als het om een overkoepelende term gaat.
    Door alleen de regels over te houden waar unit uit meer dan 4 characters bestaat,
    houden we de regels over blokken over.'''
    dataf = df.copy()
    return dataf.loc[dataf.Unit.str.len() > 4, ]

# %%
files = ['../Data/BROS HSR realisations 2019-2020, 14.5.2022-Blokcoordinatoren en planningsgroepsleden.xlsx',
        '../Data/BROS HSR realisations 2020-2021, 11.2.2022-Blokcoordinatoren en planningsgroepsleden.xlsx',
        '../Data/BROS HSR realisations 2021-2022, 14.5.2022-Blokcoordinatoren en planningsgroepsleden.xlsx']

onderwijs = pd.DataFrame()

# zet alle jaren in 1 df
for jaar, filename in zip(range(2019, 2022), files):
    onderwijs = pd.concat([onderwijs, (pd.read_excel(filename,
                                                     sheet_name='Realisations')
                                       .dropna(subset=['Unit'])
                                       .assign(Year=jaar)
                                       .pipe(drop_niet_blokken)
                                       .drop_duplicates())],
                          axis=0)
    
onderwijs['UnitYear'] = [f"{unit}_{year}" for unit, year in zip(onderwijs['Unit'], onderwijs['Year'])]
onderwijs['Prefix'] = onderwijs['Prefix'].fillna('')
onderwijs['Naam'] = onderwijs.Initials + " " + onderwijs.Prefix + " " + onderwijs.Name

onderwijs
# Out:
#         Unit                                          Unit name Category  \
# 3    GZW1021                              Een Leven Lang Gezond        B
# 4    GZW1022                        Bedreigingen van Gezondheid        B
# 5    GZW1024                     Gezondheid, Voeding en Bewegen        C
# 6    GZW1025                           Zorg(en) voor Gezondheid        C
# 7    GZW1025                           Zorg(en) voor Gezondheid        B
# ..       ...                                                ...      ...
# 104  MPH0006                            Global Health Economics        C
# 105  MPH0007                           Global Health Management        C
# 108  HMS4802        The Enterpreneurial Healthcare Professional        C
# 109  HMS4802        The Enterpreneurial Healthcare Professional        B
# 114   HDT-L2  Digital Technology at the Social-technical Sys...        C
#
#           Name Prefix Initials Department                          Role name  \
# 3    Zwakhalen             SMG        HSR              Member Planning Group
# 4    Haastregt    van      JCM        HSR              Member Planning Group
# 5     Zijlstra             GAR        HSR         Coordinator Planning Group
# 6    Groothuis               S        HSR         Coordinator Planning Group
# 7        Evers            SMAA        HSR              Member Planning Group
# ..         ...    ...      ...        ...                                ...
# 104    Pavlova              MI        HSR         Coordinator Planning Group
# 105    Pavlova              MI        HSR         Coordinator Planning Group
# 108       Raak    van      AJA        HSR         Coordinator Planning Group
# 109     Govers             MJG        HSR              Member Planning Group
# 114     Roumen               C        HSR  Developer (Block/Track/Elective)
#
#      Year      UnitYear               Naam
# 3    2019  GZW1021_2019     SMG  Zwakhalen
# 4    2019  GZW1022_2019  JCM van Haastregt
# 5    2019  GZW1024_2019      GAR  Zijlstra
# 6    2019  GZW1025_2019       S  Groothuis
# 7    2019  GZW1025_2019        SMAA  Evers
# ..    ...           ...                ...
# 104  2021  MPH0006_2021        MI  Pavlova
# 105  2021  MPH0007_2021        MI  Pavlova
# 108  2021  HMS4802_2021       AJA van Raak
# 109  2021  HMS4802_2021        MJG  Govers
# 114  2021   HDT-L2_2021          C  Roumen
#
# [283 rows x 11 columns]

# %%
from itertools import combinations

for unityear in onderwijs.UnitYear.unique():
    
    # get rows of that unityear
    # get staff in that unityear
    staff = onderwijs.loc[onderwijs.UnitYear == unityear, 'Naam'].values

    # get all combinations of 2 of staff in that unityear
    for c in list(combinations(staff, 2)):
        print(unityear, c)
# Out:
# GZW1025_2019 ('S  Groothuis', 'SMAA  Evers')
# GZW1025_2019 ('S  Groothuis', 'WNJ  Groot')
# GZW1025_2019 ('SMAA  Evers', 'WNJ  Groot')
# BMZ3026_2019 ('AMJ  Elissen', 'GAR  Zijlstra')
# BMZ2021_2019 ('N de Jong', 'BS de Boer')
# BMZ2021_2019 ('N de Jong', 'S  Groothuis')
# BMZ2021_2019 ('N de Jong', 'JPH  Hamers')
# BMZ2021_2019 ('BS de Boer', 'S  Groothuis')
# BMZ2021_2019 ('BS de Boer', 'JPH  Hamers')
# BMZ2021_2019 ('S  Groothuis', 'JPH  Hamers')
# BMZ2022_2019 ('ATG  Paulus', 'RMWA  Drost')
# BMZ2022_2019 ('ATG  Paulus', 'AMJ  Elissen')
# BMZ2022_2019 ('ATG  Paulus', 'SMAA  Evers')
# BMZ2022_2019 ('ATG  Paulus', 'MJC  Hiligsmann')
# BMZ2022_2019 ('RMWA  Drost', 'AMJ  Elissen')
# BMZ2022_2019 ('RMWA  Drost', 'SMAA  Evers')
# BMZ2022_2019 ('RMWA  Drost', 'MJC  Hiligsmann')
# BMZ2022_2019 ('AMJ  Elissen', 'SMAA  Evers')
# BMZ2022_2019 ('AMJ  Elissen', 'MJC  Hiligsmann')
# BMZ2022_2019 ('SMAA  Evers', 'MJC  Hiligsmann')
# BMZ2023_2019 ('JCM van Haastregt', 'MHC  Bleijlevens')
# BMZ2023_2019 ('JCM van Haastregt', 'DFL  Hertroijs')
# BMZ2023_2019 ('JCM van Haastregt', 'T  Thoma')
# BMZ2023_2019 ('MHC  Bleijlevens', 'DFL  Hertroijs')
# BMZ2023_2019 ('MHC  Bleijlevens', 'T  Thoma')
# BMZ2023_2019 ('DFL  Hertroijs', 'T  Thoma')
# BMZ2024_2019 ('SMG  Zwakhalen', 'MHC  Bleijlevens')
# BMZ2024_2019 ('SMG  Zwakhalen', 'JMM  Meijers')
# BMZ2024_2019 ('SMG  Zwakhalen', 'T  Thoma')
# BMZ2024_2019 ('MHC  Bleijlevens', 'JMM  Meijers')
# BMZ2024_2019 ('MHC  Bleijlevens', 'T  Thoma')
# BMZ2024_2019 ('JMM  Meijers', 'T  Thoma')
# BMZ2025_2019 ('MJG  Govers', 'IM van der Putten')
# BMZ2025_2019 ('MJG  Govers', 'AJA van Raak')
# BMZ2025_2019 ('IM van der Putten', 'AJA van Raak')
# BMZ2026_2019 ('MHC  Bleijlevens', 'JCM van Haastregt')
# BMZ2026_2019 ('MHC  Bleijlevens', 'SF  Metzelthin')
# BMZ2026_2019 ('MHC  Bleijlevens', 'SMG  Zwakhalen')
# BMZ2026_2019 ('JCM van Haastregt', 'SF  Metzelthin')
# BMZ2026_2019 ('JCM van Haastregt', 'SMG  Zwakhalen')
# BMZ2026_2019 ('SF  Metzelthin', 'SMG  Zwakhalen')
# BMZ3025_2019 ('H  Verbeek', 'JCM van Haastregt')
# BMZ3025_2019 ('H  Verbeek', 'D  Ruwaard')
# BMZ3025_2019 ('JCM van Haastregt', 'D  Ruwaard')
# DTZ2022_2019 ('MD  Spreeuwenberg', 'S  Vluggen')
# EPH1008_2019 ('N de Jong', 'BS de Boer')
# PGZ2025_2019 ('SMAA  Evers', 'MI  Pavlova')
# HPI4001_2019 ('MJC  Hiligsmann', 'SMAA  Evers')
# HPI4001_2019 ('MJC  Hiligsmann', 'ATG  Paulus')
# HPI4001_2019 ('MJC  Hiligsmann', 'DD  Westra')
# HPI4001_2019 ('SMAA  Evers', 'ATG  Paulus')
# HPI4001_2019 ('SMAA  Evers', 'DD  Westra')
# HPI4001_2019 ('ATG  Paulus', 'DD  Westra')
# HPI4002_2019 ('GAR  Zijlstra', 'AMJ  Elissen')
# HPI4002_2019 ('GAR  Zijlstra', 'JCM van Haastregt')
# HPI4002_2019 ('GAR  Zijlstra', 'IM van der Putten')
# HPI4002_2019 ('AMJ  Elissen', 'JCM van Haastregt')
# HPI4002_2019 ('AMJ  Elissen', 'IM van der Putten')
# HPI4002_2019 ('JCM van Haastregt', 'IM van der Putten')
# HPI4005_2019 ('RMWA  Drost', 'MJC  Hiligsmann')
# HPI4005_2019 ('RMWA  Drost', 'MI  Pavlova')
# HPI4005_2019 ('RMWA  Drost', 'IM van der Putten')
# HPI4005_2019 ('MJC  Hiligsmann', 'MI  Pavlova')
# HPI4005_2019 ('MJC  Hiligsmann', 'IM van der Putten')
# HPI4005_2019 ('MI  Pavlova', 'IM van der Putten')
# HPI4007_2019 ('MI  Pavlova', 'SMAA  Evers')
# HPI4007_2019 ('MI  Pavlova', 'MJG  Govers')
# HPI4007_2019 ('MI  Pavlova', 'IM van der Putten')
# HPI4007_2019 ('SMAA  Evers', 'MJG  Govers')
# HPI4007_2019 ('SMAA  Evers', 'IM van der Putten')
# HPI4007_2019 ('MJG  Govers', 'IM van der Putten')
# HPI4008_2019 ('DD  Westra', 'MJG  Govers')
# HPI4008_2019 ('DD  Westra', 'AJA van Raak')
# HPI4008_2019 ('MJG  Govers', 'AJA van Raak')
# HPI4009_2019 ('AMJ  Elissen', 'AJA van Raak')
# HPI4009_2019 ('AMJ  Elissen', 'D  Ruwaard')
# HPI4009_2019 ('AMJ  Elissen', 'DD  Westra')
# HPI4009_2019 ('AJA van Raak', 'D  Ruwaard')
# HPI4009_2019 ('AJA van Raak', 'DD  Westra')
# HPI4009_2019 ('D  Ruwaard', 'DD  Westra')
# HPI4010_2019 ('MJG  Govers', 'S  Groothuis')
# HPI4010_2019 ('MJG  Govers', 'AJA van Raak')
# HPI4010_2019 ('S  Groothuis', 'AJA van Raak')
# MPH0006_2019 ('MI  Pavlova', 'WNJ  Groot')
# MPH0006_2019 ('MI  Pavlova', 'E  Miteniece')
# MPH0006_2019 ('WNJ  Groot', 'E  Miteniece')
# MPH0007_2019 ('IM van der Putten', 'RMWA  Drost')
# MPH0007_2019 ('IM van der Putten', 'MJG  Govers')
# MPH0007_2019 ('RMWA  Drost', 'MJG  Govers')
# HMS4802_2019 ('AJA van Raak', 'MJG  Govers')
# RHS4021_2019 ('SMAA  Evers', 'CD  Dirksen')
# RHS4021_2019 ('SMAA  Evers', 'MJC  Hiligsmann')
# RHS4021_2019 ('SMAA  Evers', 'BFM  Wijnen')
# RHS4021_2019 ('CD  Dirksen', 'MJC  Hiligsmann')
# RHS4021_2019 ('CD  Dirksen', 'BFM  Wijnen')
# RHS4021_2019 ('MJC  Hiligsmann', 'BFM  Wijnen')
# RHS4024_2019 ('CD  Dirksen', 'MJC  Hiligsmann')
# GZW1025_2020 ('S  Groothuis', 'SMAA  Evers')
# GZW1025_2020 ('S  Groothuis', 'WNJ  Groot')
# GZW1025_2020 ('SMAA  Evers', 'WNJ  Groot')
# BMZ3026_2020 ('PMG  Erkens', 'GAR  Zijlstra')
# BMZ2021_2020 ('N de Jong', 'BS de Boer')
# BMZ2021_2020 ('N de Jong', 'S  Groothuis')
# BMZ2021_2020 ('N de Jong', 'JPH  Hamers')
# BMZ2021_2020 ('BS de Boer', 'S  Groothuis')
# BMZ2021_2020 ('BS de Boer', 'JPH  Hamers')
# BMZ2021_2020 ('S  Groothuis', 'JPH  Hamers')
# BMZ2022_2020 ('ATG  Paulus', 'RMWA  Drost')
# BMZ2022_2020 ('ATG  Paulus', 'AMJ  Elissen')
# BMZ2022_2020 ('ATG  Paulus', 'SMAA  Evers')
# BMZ2022_2020 ('ATG  Paulus', 'MJC  Hiligsmann')
# BMZ2022_2020 ('RMWA  Drost', 'AMJ  Elissen')
# BMZ2022_2020 ('RMWA  Drost', 'SMAA  Evers')
# BMZ2022_2020 ('RMWA  Drost', 'MJC  Hiligsmann')
# BMZ2022_2020 ('AMJ  Elissen', 'SMAA  Evers')
# BMZ2022_2020 ('AMJ  Elissen', 'MJC  Hiligsmann')
# BMZ2022_2020 ('SMAA  Evers', 'MJC  Hiligsmann')
# BMZ2023_2020 ('JCM van Haastregt', 'MHC  Bleijlevens')
# BMZ2023_2020 ('JCM van Haastregt', 'DFL  Hertroijs')
# BMZ2023_2020 ('JCM van Haastregt', 'T  Thoma')
# BMZ2023_2020 ('MHC  Bleijlevens', 'DFL  Hertroijs')
# BMZ2023_2020 ('MHC  Bleijlevens', 'T  Thoma')
# BMZ2023_2020 ('DFL  Hertroijs', 'T  Thoma')
# BMZ2024_2020 ('SF  Metzelthin', 'MHC  Bleijlevens')
# BMZ2024_2020 ('SF  Metzelthin', 'JMM  Meijers')
# BMZ2024_2020 ('SF  Metzelthin', 'T  Thoma')
# BMZ2024_2020 ('SF  Metzelthin', 'S  Vluggen')
# BMZ2024_2020 ('MHC  Bleijlevens', 'JMM  Meijers')
# BMZ2024_2020 ('MHC  Bleijlevens', 'T  Thoma')
# BMZ2024_2020 ('MHC  Bleijlevens', 'S  Vluggen')
# BMZ2024_2020 ('JMM  Meijers', 'T  Thoma')
# BMZ2024_2020 ('JMM  Meijers', 'S  Vluggen')
# BMZ2024_2020 ('T  Thoma', 'S  Vluggen')
# BMZ2025_2020 ('MJG  Govers', 'IM van der Putten')
# BMZ2025_2020 ('MJG  Govers', 'AJA van Raak')
# BMZ2025_2020 ('IM van der Putten', 'AJA van Raak')
# BMZ2026_2020 ('MHC  Bleijlevens', 'PMG  Erkens')
# BMZ2026_2020 ('MHC  Bleijlevens', 'JCM van Haastregt')
# BMZ2026_2020 ('MHC  Bleijlevens', 'SF  Metzelthin')
# BMZ2026_2020 ('PMG  Erkens', 'JCM van Haastregt')
# BMZ2026_2020 ('PMG  Erkens', 'SF  Metzelthin')
# BMZ2026_2020 ('JCM van Haastregt', 'SF  Metzelthin')
# BMZ3025_2020 ('H  Verbeek', 'JCM van Haastregt')
# BMZ3025_2020 ('H  Verbeek', 'D  Ruwaard')
# BMZ3025_2020 ('JCM van Haastregt', 'D  Ruwaard')
# DTZ2022_2020 ('MD  Spreeuwenberg', 'S  Vluggen')
# PGZ2025_2020 ('SMAA  Evers', 'MI  Pavlova')
# HPI4001_2020 ('MJC  Hiligsmann', 'SMAA  Evers')
# HPI4001_2020 ('MJC  Hiligsmann', 'ATG  Paulus')
# HPI4001_2020 ('MJC  Hiligsmann', 'DD  Westra')
# HPI4001_2020 ('SMAA  Evers', 'ATG  Paulus')
# HPI4001_2020 ('SMAA  Evers', 'DD  Westra')
# HPI4001_2020 ('ATG  Paulus', 'DD  Westra')
# HPI4002_2020 ('GAR  Zijlstra', 'AMJ  Elissen')
# HPI4002_2020 ('GAR  Zijlstra', 'JCM van Haastregt')
# HPI4002_2020 ('GAR  Zijlstra', 'IM van der Putten')
# HPI4002_2020 ('AMJ  Elissen', 'JCM van Haastregt')
# HPI4002_2020 ('AMJ  Elissen', 'IM van der Putten')
# HPI4002_2020 ('JCM van Haastregt', 'IM van der Putten')
# HPI4005_2020 ('RMWA  Drost', 'MJC  Hiligsmann')
# HPI4005_2020 ('RMWA  Drost', 'MI  Pavlova')
# HPI4005_2020 ('RMWA  Drost', 'IM van der Putten')
# HPI4005_2020 ('MJC  Hiligsmann', 'MI  Pavlova')
# HPI4005_2020 ('MJC  Hiligsmann', 'IM van der Putten')
# HPI4005_2020 ('MI  Pavlova', 'IM van der Putten')
# HPI4007_2020 ('MI  Pavlova', 'SMAA  Evers')
# HPI4007_2020 ('MI  Pavlova', 'MJG  Govers')
# HPI4007_2020 ('MI  Pavlova', 'WNJ  Groot')
# HPI4007_2020 ('SMAA  Evers', 'MJG  Govers')
# HPI4007_2020 ('SMAA  Evers', 'WNJ  Groot')
# HPI4007_2020 ('MJG  Govers', 'WNJ  Groot')
# HPI4008_2020 ('DD  Westra', 'MJG  Govers')
# HPI4008_2020 ('DD  Westra', 'AJA van Raak')
# HPI4008_2020 ('MJG  Govers', 'AJA van Raak')
# HPI4009_2020 ('AMJ  Elissen', 'AJA van Raak')
# HPI4009_2020 ('AMJ  Elissen', 'D  Ruwaard')
# HPI4009_2020 ('AMJ  Elissen', 'DD  Westra')
# HPI4009_2020 ('AJA van Raak', 'D  Ruwaard')
# HPI4009_2020 ('AJA van Raak', 'DD  Westra')
# HPI4009_2020 ('D  Ruwaard', 'DD  Westra')
# HPI4010_2020 ('MJG  Govers', 'S  Groothuis')
# HPI4010_2020 ('MJG  Govers', 'AJA van Raak')
# HPI4010_2020 ('S  Groothuis', 'AJA van Raak')
# MPH0006_2020 ('MI  Pavlova', 'WNJ  Groot')
# MPH0007_2020 ('MI  Pavlova', 'RMWA  Drost')
# MPH0007_2020 ('MI  Pavlova', 'MJG  Govers')
# MPH0007_2020 ('RMWA  Drost', 'MJG  Govers')
# HMS4802_2020 ('MJG  Govers', 'AJA van Raak')
# GZW1025_2021 ('RMWA  Drost', 'SMAA  Evers')
# GZW1025_2021 ('RMWA  Drost', 'S  Groothuis')
# GZW1025_2021 ('RMWA  Drost', 'S  Groothuis')
# GZW1025_2021 ('SMAA  Evers', 'S  Groothuis')
# GZW1025_2021 ('SMAA  Evers', 'S  Groothuis')
# GZW1025_2021 ('S  Groothuis', 'S  Groothuis')
# BMZ3026_2021 ('PMG  Erkens', 'GAR  Zijlstra')
# BMZ2021_2021 ('N de Jong', 'BS de Boer')
# BMZ2021_2021 ('N de Jong', 'S  Groothuis')
# BMZ2021_2021 ('N de Jong', 'JPH  Hamers')
# BMZ2021_2021 ('BS de Boer', 'S  Groothuis')
# BMZ2021_2021 ('BS de Boer', 'JPH  Hamers')
# BMZ2021_2021 ('S  Groothuis', 'JPH  Hamers')
# BMZ2022_2021 ('ATG  Paulus', 'RMWA  Drost')
# BMZ2022_2021 ('ATG  Paulus', 'AMJ  Elissen')
# BMZ2022_2021 ('ATG  Paulus', 'SMAA  Evers')
# BMZ2022_2021 ('ATG  Paulus', 'MJC  Hiligsmann')
# BMZ2022_2021 ('RMWA  Drost', 'AMJ  Elissen')
# BMZ2022_2021 ('RMWA  Drost', 'SMAA  Evers')
# BMZ2022_2021 ('RMWA  Drost', 'MJC  Hiligsmann')
# BMZ2022_2021 ('AMJ  Elissen', 'SMAA  Evers')
# BMZ2022_2021 ('AMJ  Elissen', 'MJC  Hiligsmann')
# BMZ2022_2021 ('SMAA  Evers', 'MJC  Hiligsmann')
# BMZ2023_2021 ('JCM van Haastregt', 'MHC  Bleijlevens')
# BMZ2023_2021 ('JCM van Haastregt', 'DFL  Hertroijs')
# BMZ2023_2021 ('JCM van Haastregt', 'MEAL  Kroese')
# BMZ2023_2021 ('MHC  Bleijlevens', 'DFL  Hertroijs')
# BMZ2023_2021 ('MHC  Bleijlevens', 'MEAL  Kroese')
# BMZ2023_2021 ('DFL  Hertroijs', 'MEAL  Kroese')
# BMZ2024_2021 ('SF  Metzelthin', 'MHC  Bleijlevens')
# BMZ2024_2021 ('SF  Metzelthin', 'JMM  Meijers')
# BMZ2024_2021 ('SF  Metzelthin', 'T  Thoma')
# BMZ2024_2021 ('SF  Metzelthin', 'S  Vluggen')
# BMZ2024_2021 ('MHC  Bleijlevens', 'JMM  Meijers')
# BMZ2024_2021 ('MHC  Bleijlevens', 'T  Thoma')
# BMZ2024_2021 ('MHC  Bleijlevens', 'S  Vluggen')
# BMZ2024_2021 ('JMM  Meijers', 'T  Thoma')
# BMZ2024_2021 ('JMM  Meijers', 'S  Vluggen')
# BMZ2024_2021 ('T  Thoma', 'S  Vluggen')
# BMZ2025_2021 ('MJG  Govers', 'IM van der Putten')
# BMZ2025_2021 ('MJG  Govers', 'AJA van Raak')
# BMZ2025_2021 ('IM van der Putten', 'AJA van Raak')
# BMZ2026_2021 ('MHC  Bleijlevens', 'PMG  Erkens')
# BMZ2026_2021 ('MHC  Bleijlevens', 'JCM van Haastregt')
# BMZ2026_2021 ('MHC  Bleijlevens', 'SF  Metzelthin')
# BMZ2026_2021 ('PMG  Erkens', 'JCM van Haastregt')
# BMZ2026_2021 ('PMG  Erkens', 'SF  Metzelthin')
# BMZ2026_2021 ('JCM van Haastregt', 'SF  Metzelthin')
# BMZ3025_2021 ('H  Verbeek', 'JCM van Haastregt')
# BMZ3025_2021 ('H  Verbeek', 'D  Ruwaard')
# BMZ3025_2021 ('JCM van Haastregt', 'D  Ruwaard')
# DTZ2022_2021 ('MD  Spreeuwenberg', 'S  Vluggen')
# PGZ2025_2021 ('SMAA  Evers', 'MI  Pavlova')
# HPI4001_2021 ('MJC  Hiligsmann', 'SMAA  Evers')
# HPI4001_2021 ('MJC  Hiligsmann', 'ATG  Paulus')
# HPI4001_2021 ('MJC  Hiligsmann', 'DD  Westra')
# HPI4001_2021 ('SMAA  Evers', 'ATG  Paulus')
# HPI4001_2021 ('SMAA  Evers', 'DD  Westra')
# HPI4001_2021 ('ATG  Paulus', 'DD  Westra')
# HPI4002_2021 ('GAR  Zijlstra', 'AMJ  Elissen')
# HPI4002_2021 ('GAR  Zijlstra', 'JCM van Haastregt')
# HPI4002_2021 ('GAR  Zijlstra', 'IM van der Putten')
# HPI4002_2021 ('AMJ  Elissen', 'JCM van Haastregt')
# HPI4002_2021 ('AMJ  Elissen', 'IM van der Putten')
# HPI4002_2021 ('JCM van Haastregt', 'IM van der Putten')
# HPI4005_2021 ('RMWA  Drost', 'MJC  Hiligsmann')
# HPI4005_2021 ('RMWA  Drost', 'MI  Pavlova')
# HPI4005_2021 ('RMWA  Drost', 'IM van der Putten')
# HPI4005_2021 ('MJC  Hiligsmann', 'MI  Pavlova')
# HPI4005_2021 ('MJC  Hiligsmann', 'IM van der Putten')
# HPI4005_2021 ('MI  Pavlova', 'IM van der Putten')
# HPI4007_2021 ('MI  Pavlova', 'SMAA  Evers')
# HPI4007_2021 ('MI  Pavlova', 'MJG  Govers')
# HPI4007_2021 ('MI  Pavlova', 'WNJ  Groot')
# HPI4007_2021 ('SMAA  Evers', 'MJG  Govers')
# HPI4007_2021 ('SMAA  Evers', 'WNJ  Groot')
# HPI4007_2021 ('MJG  Govers', 'WNJ  Groot')
# HPI4008_2021 ('DD  Westra', 'MJG  Govers')
# HPI4008_2021 ('DD  Westra', 'AJA van Raak')
# HPI4008_2021 ('MJG  Govers', 'AJA van Raak')
# HPI4009_2021 ('AMJ  Elissen', 'AJA van Raak')
# HPI4009_2021 ('AMJ  Elissen', 'D  Ruwaard')
# HPI4009_2021 ('AMJ  Elissen', 'DD  Westra')
# HPI4009_2021 ('AJA van Raak', 'D  Ruwaard')
# HPI4009_2021 ('AJA van Raak', 'DD  Westra')
# HPI4009_2021 ('D  Ruwaard', 'DD  Westra')
# HPI4010_2021 ('MJG  Govers', 'S  Groothuis')
# HPI4010_2021 ('MJG  Govers', 'AJA van Raak')
# HPI4010_2021 ('S  Groothuis', 'AJA van Raak')
# HMS4802_2021 ('AJA van Raak', 'MJG  Govers')
